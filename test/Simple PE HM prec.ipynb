# %% [markdown]
# ## Tests of higher harmonics and precession sample generation

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import copy

from pycbc import conversions, psd
from pycbc.filter import match

from simple_pe.param_est import metric, pe
from pesummary.utils.samples_dict import SamplesDict
from pesummary.gw.conversions import convert

# %%
import logging
_logger = logging.getLogger('PESummary')
_logger.setLevel(logging.CRITICAL + 10)

# %%
npts = int(1e6)

# %%
ifos = ['H1', 'L1', 'V1']

psds = {'H1': 'aLIGOMidHighSensitivityP1200087',
        'L1': 'aLIGOMidHighSensitivityP1200087',
        'V1': 'AdVMidHighSensitivityP1200087',
        'f_low': 20.,
        'f_high': 8192,
        'length': 32
        }

psds['delta_f'] = 1. / psds['length']

approximant = 'IMRPhenomXPHM'

# %%
pycbc_psd = {}
for ifo in ifos:
    pycbc_psd[ifo] = psd.analytical.from_string(psds[ifo], psds['length'] * psds['f_high'] + 1, psds['delta_f'],
                                                psds['f_low'])

pycbc_psd['harm'] = 3. / sum([1. / pycbc_psd[ifo] for ifo in ifos])
# Out:
# /home/spxsf2/miniconda3/envs/igwn-py38/lib/python3.8/site-packages/pycbc/types/array.py:375: RuntimeWarning: divide by zero encountered in true_divide
#   return self._data.__rtruediv__(other)

# %%
m1 = 30.
m2 = 10.
mc = conversions.mchirp_from_mass1_mass2(m1, m2)
eta = conversions.eta_from_mass1_mass2(m1, m2)
s1z = 0.3
s2z = 0.
chi_eff = conversions.chi_eff(m1, m2, s1z, s2z)
snr = 18

a_net = 0.2

# %%
params = {'chirp_mass': mc,
          'symmetric_mass_ratio': eta,
          'chi_eff':chi_eff
        }

# %%
dxs = {'chirp_mass': 0.1,
      'symmetric_mass_ratio': 0.03,
      'chi_eff': 0.1}

# %% [markdown]
# Generate an initial samples dict in mass and spin space

# %%
pts = {}
for x in params:
    pts[x] = np.random.uniform(params[x] - dxs[x], params[x] + dxs[x], npts)

# %%
samples = SamplesDict(pts)

# %% [markdown]
# Initial distributions

# %%
for x in samples.keys():
    plt.figure()
    plt.hist(samples[x], density=True)
    plt.xlabel(x)
    plt.grid()

# %% [markdown]
# Generate theta_jn

# %%
thetas = ['uniform', 'left_circ', 'right_circ']
s = {}

# %%
for theta in thetas:
    s[theta] = pe.generate_theta_jn(samples, theta_dist = theta)
    plt.hist(s[theta]['theta_jn'], density=True, label=theta, alpha=0.5, bins=50)
    
plt.xlabel('theta_jn')
plt.grid()
plt.legend()

# %%
for theta in thetas:
    plt.hist(s[theta]['cos_theta_jn'], density=True, label=theta, alpha=0.5, bins=50)
    
plt.xlabel('cos_theta_jn')
plt.grid()
plt.legend()

# %% [markdown]
# #### Verify theta_jn distributions

# %% [markdown]
# Generate uniform in cosi and volume and keep points which have a specific snr in left/right polarization

# %%
d = np.random.power(3, npts)
cosi = np.random.uniform(-1, 1, npts)
rho_l = (1 + cosi)**4/(4 * d)**2

# %%
plt.hist(d, bins=50, density=True)
x = np.linspace(0,1,100)
plt.plot(x, 3 * x**2)
plt.grid()
plt.xlabel('distance')
# Out:
# Text(0.5, 0, 'distance')

# %%
plt.hist(cosi, bins=50, density=True)
ci = np.linspace(-1, 1, 100)
plt.plot(ci, 0.5 * np.ones_like(ci))
plt.grid()
plt.xlabel('cos theta')
# Out:
# Text(0.5, 0, 'cos theta')

# %%
k = (rho_l < 1.1) & (rho_l > 1.0)

# %%
plt.hist(d[k], bins=50)
plt.grid()
plt.xlabel('distance')
# Out:
# Text(0.5, 0, 'distance')

# %%
plt.hist(cosi[k], bins=100, density=True)
plt.plot(ci, ((1 + ci)/2)**6 * 7/2)
plt.grid()
plt.ylabel('cos theta')
# Out:
# Text(0, 0.5, 'cos theta')

# %%
plt.hist(s['left_circ']['cos_theta_jn'], bins=100, density=True, alpha=0.4)
plt.hist(cosi[k], bins=100, density=True, alpha=0.4)
plt.xlabel('cos theta')

plt.grid()

# %% [markdown]
# ## Generate hm and prec SNRS

# %% [markdown]
# Generate chi_p and theta_jn points

# %%
samples = pe.generate_chi_p(samples, 'uniform')
samples = pe.generate_theta_jn(samples, theta_dist = 'left_circ')

# %%
for x in samples.keys():
    plt.figure()
    plt.hist(samples[x], density=True, bins=50)
    plt.xlabel(x)
    plt.grid()

# %%
modes = ['33'] #, '44']
hm_interp_dirs = ['chirp_mass', 'symmetric_mass_ratio', 'chi_eff']
prec_interp_dirs = ['symmetric_mass_ratio', 'chi_eff', 'chi_p']
interp_points = 7
approximant="IMRPhenomXPHM"

# %%
samples = pe.calculate_rho_lm(samples, pycbc_psd['harm'], psds['f_low'], snr, modes,
                                 hm_interp_dirs, interp_points, approximant)

samples = pe.calculate_rho_2nd_pol(samples, a_net, snr)

samples = pe.calculate_rho_p(samples, pycbc_psd['harm'], psds['f_low'], snr,
                                 prec_interp_dirs, interp_points, approximant)

# %% [markdown]
# ## SNR dependence on parameters

# %%
var = ['theta_jn', 'rho_2pol']
plt.figure(figsize=(12,8))
plt.scatter(samples[var[0]], samples[var[1]])
plt.xlabel(var[0])
plt.ylabel(var[1])
plt.ylim([0,10])
plt.grid()

# %%
var = ['symmetric_mass_ratio', 'cos_theta_jn']
color = 'rho_33'
plt.figure(figsize=(12,8))
plt.scatter(samples[var[0]], samples[var[1]], c=samples[color])
plt.xlabel(var[0])
plt.ylabel(var[1])
plt.colorbar()
plt.grid()

# %%
var = ['chi_p', 'cos_theta_jn']
color = 'rho_p'
plt.figure(figsize=(12,8))
plt.scatter(samples[var[0]], samples[var[1]], c=samples[color])
plt.xlabel(var[0])
plt.ylabel(var[1])
plt.colorbar()

# %% [markdown]
# ### Reweight points based on observed SNRs

# %%
rho = {}
rho['33'] = 4.0
rho['p'] = 3.0
rho['2pol']= 2.0

# %%
samples = pe.calculate_hm_prec_probs(samples, {'33':rho['33']}, rho['p'], rho['2pol'])

# %%
var = '2pol'
plt.figure(figsize=(12,8))
plt.scatter(samples['rho_' + var], samples['p_' + var])
plt.xlim(0, 2* rho[var])
plt.axvline(rho[var], c='r', linewidth=3)
plt.xlabel('rho_' + var)
plt.ylabel('p_' + var)
# Out:
# Text(0, 0.5, 'p_2pol')

# %%
var = 'theta_jn'
snr = '2pol'
plt.figure(figsize=(12,8))
fig, ax = plt.subplots(2)
ax[0].scatter(samples[var], samples['rho_' + snr])
ax[0].set_ylim(0, 2* rho[snr])
ax[0].axhline(rho[snr], c='r', linewidth=3)
ax[0].set_ylabel('rho_' + snr)

ax[1].scatter(samples[var], samples['p_' + snr])
ax[1].set_ylabel('p_' + var)

plt.xlabel(var[0])
# Out:
# Text(0.5, 0, 't')

# %%
var = '33'
plt.figure(figsize=(12,8))
plt.scatter(samples['rho_' + var], samples['p_' + var])
plt.xlim(0, 2* rho[var])
plt.axvline(rho[var], c='r', linewidth=3)
plt.xlabel('rho_' + var)
plt.ylabel('p_' + var)
# Out:
# Text(0, 0.5, 'p_33')

# %%
var = ['symmetric_mass_ratio', 'theta_jn']
color = 'p_33'
plt.figure(figsize=(12,8))
plt.scatter(samples[var[0]], samples[var[1]], c=samples[color])
plt.xlabel(var[0])
plt.ylabel(var[1])
plt.colorbar(label=color)

# %%
var = 'p'
plt.figure(figsize=(12,8))
plt.scatter(samples['rho_' + var], samples['p_' + var])
plt.xlim(0, 2* rho[var])
plt.axvline(rho[var], c='r', linewidth=3)
plt.xlabel('rho_' + var)
plt.ylabel('p_' + var)
# Out:
# Text(0, 0.5, 'p_p')

# %%
var = ['chi_p', 'theta_jn']
color = 'p_p'
plt.figure(figsize=(12,8))
plt.scatter(samples[var[0]], samples[var[1]], c=samples[color])
plt.xlabel(var[0])
plt.ylabel(var[1])
plt.colorbar(label=color)

# %%
var = ['chi_p', 'theta_jn']
color = 'weight'
plt.figure(figsize=(12,8))
plt.scatter(samples[var[0]], samples[var[1]], c=samples[color])
plt.xlabel(var[0])
plt.ylabel(var[1])
plt.colorbar(label=color)
